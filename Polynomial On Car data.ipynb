# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor

# %%
data=pd.read_csv("CarPrice_Data.csv")
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
X=data["horsepower"].values
X=X.reshape(-1,1)

# %%
Y=data["price"].values
Y=Y.reshape(-1,1)

# %%
plt.scatter(X,Y)

# %%
lr=LinearRegression()
lr.fit(X,Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,Y,color="red")
plt.plot(X,lr.predict(X),color="blue")
plt.xlabel("City mpg")
plt.ylabel("Price")
plt.title("City_mpg vs Car_Price")
# Out:
# Text(0.5, 1.0, 'City_mpg vs Car_Price')

# %%
polynomial_reg=PolynomialFeatures(degree=2)
real_x_poly=polynomial_reg.fit_transform(X)
Y_poly=polynomial_reg.fit_transform(Y)
training_x,testing_x,training_y,testing_y= train_test_split(real_x_poly,Y_poly,test_size=0.2,random_state=0)

# %%
polynomial_reg.fit(training_x,training_y)
# Out:
# PolynomialFeatures()

# %%
LR=LinearRegression()
LR.fit(training_x,training_y)
# Out:
# LinearRegression()

# %%
plt.scatter(training_x,training_y,color="red")
plt.plot(training_x,LR.predict(training_x),color="blue")
plt.xlabel("Confirmed Case")
plt.ylabel("Death")
plt.title("Covid-19 Death curve")
# Out:
# Text(0.5, 1.0, 'Covid-19 Death curve')

# %%
LR.predict(training_x)
# Out:
# array([[1.00000000e+00, 1.49438069e+04, 2.58873753e+08],
#        [1.00000000e+00, 2.16747568e+04, 5.26164556e+08],
#        [1.00000000e+00, 1.41234232e+04, 2.31194534e+08],
#        [1.00000000e+00, 1.42871269e+04, 2.36628473e+08],
#        [1.00000000e+00, 7.41630886e+03, 4.89789841e+07],
#        [1.00000000e+00, 7.41630886e+03, 4.89789841e+07],
#        [1.00000000e+00, 1.99640393e+04, 4.51699014e+08],
#        [1.00000000e+00, 1.42871269e+04, 2.36628473e+08],
#        [1.00000000e+00, 1.00914548e+04, 1.11905539e+08],
#        [1.00000000e+00, 1.91156755e+04, 4.16376954e+08],
#        [1.00000000e+00, 5.40698308e+03, 1.07943712e+07],
#        [1.00000000e+00, 7.72823391e+03, 5.56178240e+07],
#        [1.00000000e+00, 9.93260103e+03, 1.07796358e+08],
#        [1.00000000e+00, 2.51521520e+04, 6.90381323e+08],
#        [1.00000000e+00, 2.25371106e+04, 5.65308038e+08],
#        [1.00000000e+00, 6.79469717e+03, 3.63127315e+07],
# ...

# %%
training_y
# Out:
# array([[1.00000000e+00, 1.74500000e+04, 3.04502500e+08],
#        [1.00000000e+00, 3.41840000e+04, 1.16854586e+09],
#        [1.00000000e+00, 1.50400000e+04, 2.26201600e+08],
#        [1.00000000e+00, 1.12590000e+04, 1.26765081e+08],
#        [1.00000000e+00, 7.60900000e+03, 5.78968810e+07],
#        [1.00000000e+00, 7.60900000e+03, 5.78968810e+07],
#        [1.00000000e+00, 1.48690000e+04, 2.21087161e+08],
#        [1.00000000e+00, 1.16940000e+04, 1.36749636e+08],
#        [1.00000000e+00, 8.49500000e+03, 7.21650250e+07],
#        [1.00000000e+00, 2.38750000e+04, 5.70015625e+08],
#        [1.00000000e+00, 7.09900000e+03, 5.03958010e+07],
#        [1.00000000e+00, 8.05800000e+03, 6.49313640e+07],
#        [1.00000000e+00, 1.05950000e+04, 1.12254025e+08],
#        [1.00000000e+00, 1.65030000e+04, 2.72349009e+08],
#        [1.00000000e+00, 1.83990000e+04, 3.38523201e+08],
#        [1.00000000e+00, 1.07950000e+04, 1.16532025e+08],
# ...
