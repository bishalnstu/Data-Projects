# %%
import pandas as pd

data= pd.read_csv("bmw.csv",squeeze=True)

data


data.drop_duplicates(subset=["engineSize"],keep="first",inplace=True)

data.sort_index()
# Out:
#           model  year  price transmission  mileage  fuelType  tax    mpg  \
# 0      5 Series  2014  11200    Automatic    67068    Diesel  125   57.6
# 2      5 Series  2016  16000    Automatic    62794    Diesel  160   51.4
# 3      1 Series  2017  12750    Automatic    26676    Diesel  145   72.4
# 32           i3  2016  17100    Automatic    25269     Other    0  470.8
# 66     1 Series  2016  12500       Manual    24111    Petrol  145   47.1
# 360          M5  2019  72000    Semi-Auto     3545    Petrol  145   24.1
# 621          i3  2017  19998    Automatic    41949    Hybrid  140  470.8
# 7284   5 Series  2002   1595    Automatic   115000    Petrol  325   28.5
# 7285         X3  2004   3495    Automatic   100000    Petrol  330   23.7
# 7559         M3  2010  17750       Manual    79000    Petrol  570   22.8
# 7562         M3  2004  14950    Automatic    55000    Petrol  315   23.3
# 8835         i3  2015  17400    Automatic    29465  Electric    0  470.8
# ...
